# %% [markdown]
# # Analysis of C26:0 Levels in Males with Adrenal Insufficiency
# This notebook analyzes the levels of C26:0 in males with and without adrenal insufficiency (AI). The data is sourced from the supplementary data of [Jaspers et al. (2024), *"Lipidomic biomarkers in plasma correlate with disease severity in adrenoleukodystrophy"*](https://www.nature.com/articles/s43856-024-00605-9).
#
# The goal is to reproduce some of the results in the paper, by creating plots comparing C26:0 levels across three groups:
# - Patients with no AI and younger than 55 (`NoAI`).
# - Patients with no AI and older than 55 (`NoAI >55`).
# - Patients with AI (`AI`).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path = '../SupplementaryData7.xlsx'
data = pd.read_excel(file_path, sheet_name='C26.0_data')
data.head()
# Out:
#            Males                 Unnamed: 1  \
# 0      Sample ID  Presence of Cerebral ALD
# 1  VLCFA_men_001                       CALD
# 2  VLCFA_men_002         Sample before CALD
# 3  VLCFA_men_003                       CALD
# 4  VLCFA_men_004         Sample before CALD
#
#                            Unnamed: 2                        Unnamed: 3  \
# 0  Presence of adrenal insufficiency   Severity of Spinal cord disease
# 1                                  AI                            severe
# 2                  Sample before CALD                Sample before CALD
# 3                                  AI                                na
# 4                  Sample before CALD                Sample before CALD
#
#      Unnamed: 4  Unnamed: 5          Females Unnamed: 7    Unnamed: 8
# 0  C26:0 µmol/L         NaN        Sample ID   Severity  C26:0 µmol/L
# 1       4.73192         NaN  VLCFA_women_001     severe      4.539128
# 2       3.67928         NaN  VLCFA_women_002     severe      4.111044
# 3      6.516081         NaN  VLCFA_women_003     severe      3.024844
# 4      4.677498         NaN  VLCFA_women_004     severe      3.336277

# %% [markdown]
# ## Data Cleaning
# We're interested in two columns: "Presence of adrenal insufficiency" and "C26:0 µmol/L".

# %%
data_cleaned = data.rename(columns={
    'Males': 'Sample ID',
    'Unnamed: 2': 'Presence of adrenal insufficiency',
    'Unnamed: 4': 'C26:0 µmol/L'
})

# Extract relevant data for males only
male_data = data_cleaned[['Sample ID', 'Presence of adrenal insufficiency', 'C26:0 µmol/L']].dropna()

# Filter out "Sample before CALD" rows
male_data = male_data[~male_data['Presence of adrenal insufficiency'].str.contains('Sample before CALD', na=False)]

# Convert "C26:0 µmol/L" to numeric for plotting
male_data['C26:0 µmol/L'] = pd.to_numeric(male_data['C26:0 µmol/L'], errors='coerce')

# Map the groups to simpler labels for plotting
male_data['Group'] = male_data['Presence of adrenal insufficiency'].map({
    'AI': 'AI',
    'NoAI': 'NoAI',
    'NoAI >55': 'NoAI >55'
})

male_data = male_data.dropna(subset=['Group', 'C26:0 µmol/L'])
group_order = ['NoAI', 'NoAI >55', 'AI']

# Prepare data for plotting
grouped_data = [male_data[male_data['Group'] == group]['C26:0 µmol/L'] for group in group_order]

# %% [markdown]
# ## Boxplots
#
# We can now generate boxplots and scatter plots for the three groups showing the distribution of C26:0 levels.

# %%
fig, ax = plt.subplots(figsize=(5, 5))

box_colors = ['lightblue', 'lightgreen', 'lightcoral']
boxplot = ax.boxplot(grouped_data, positions=np.arange(len(group_order)), widths=0.6, patch_artist=True,
           boxprops=dict(facecolor="lightblue", color="black"),
           medianprops=dict(color="black"),
           whiskerprops=dict(color="black"),
           capprops=dict(color="black"),
          zorder=1)
for patch, color in zip(boxplot['boxes'], box_colors):
    patch.set_facecolor(color)

# Add scatter points
for i, group in enumerate(grouped_data):
    x = np.random.normal(i, 0.1, size=len(group))  # Add jitter for better visibility
    ax.scatter(x, group, color='black', alpha=0.7, zorder=2)

ax.set_xticks(np.arange(len(group_order)))
ax.set_xticklabels(group_order, rotation=45)
ax.set_title('C26:0 Levels in Males')
ax.set_xlabel('Adrenal Insufficiency Group')
ax.set_ylabel('C26:0 µmol/L')
ax.set_ylim([0, 15])

# Tight layout
plt.tight_layout()
plt.show()
